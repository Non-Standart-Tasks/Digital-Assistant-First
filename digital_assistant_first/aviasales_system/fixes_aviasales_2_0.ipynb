# %%
import pandas as pd
pd.set_option('display.max_columns', None)

viable_proposals = pd.read_csv("viable_proposals.csv")

# %%
# df.drop_duplicates(subset=["total_duration", ""])

# %%
smpl_onetwotrip = viable_proposals[(viable_proposals.idx_new == 0) & (viable_proposals.partner_id == "20")].sort_values("price").head(1)
smpl_onetwotrip
# Out:
# Empty DataFrame
# Columns: [segment, total_duration, stops_airports, max_stops, max_stop_duration, carriers, segment_durations, segments_time, segments_airports, segments_rating, tags, is_mixed, partner_id, idx, currency, price, url, flights_baggage, flights_handbags, flight_additional_tariff_infos, viable_handbags, viable_baggage, has_handbags, has_baggage, flight_to, flight_back, tariff_to, tariff_back, rounded_price_5k, has_exchange, has_return, airlines_list_to, airlines_list_back, flight_to_time_raw, flight_back_time_raw, flight_to_time, flight_back_time, idx_new, has_blacklisted_airlines, has_preferred_airlines]
# Index: []

# %%
viable_proposals[viable_proposals.partner_id == 20]
# Out:
#                                                segment  total_duration  \
# 201  [{'flight': [{'aircraft': 'Airbus A321-100/200...             535
# 202  [{'flight': [{'aircraft': 'Airbus A321-100/200...             710
# 203  [{'flight': [{'aircraft': 'Airbus A321-100/200...            1975
# 204  [{'flight': [{'aircraft': 'Airbus A321-100/200...            1975
# 205  [{'flight': [{'aircraft': 'Airbus A330-200', '...            3405
# ..                                                 ...             ...
# 258  [{'flight': [{'aircraft': 'Airbus A321 (sharkl...            3040
# 259  [{'flight': [{'aircraft': 'Airbus A321 (sharkl...            4905
# 260  [{'flight': [{'aircraft': 'Airbus A330-200', '...            2275
# 261  [{'flight': [{'aircraft': 'Airbus A330-200', '...            4870
# 262  [{'flight': [{'aircraft': 'Airbus A321 (sharkl...            4195
#
#      stops_airports  max_stops  max_stop_duration carriers segment_durations  \
# ...

# %%
viable_proposals.sort_values(["has_exchange", "has_return", "has_handbags", "has_baggage"], ascending=False, inplace=True)
viable_proposals.drop_duplicates(subset=["idx_new", "price"], inplace=True)

# %%
viable_proposals[viable_proposals.price == 77776] # 356 to del
# Out:
#                                                segment  total_duration  \
# 357  [{'flight': [{'aircraft': 'Airbus A330-200', '...             550
# 356  [{'flight': [{'aircraft': 'Airbus A330-200', '...             550
#
#      stops_airports  max_stops  max_stop_duration carriers segment_durations  \
# 357  ['IST', 'FCO']          1                160   ['TK']            (550,)
# 356  ['IST', 'FCO']          1                160   ['TK']            (550,)
#
#                   segments_time segments_airports  segments_rating  \
# 357  [[1750988100, 1751017500]]  [['LED', 'FCO']]             7.17
# 356  [[1750988100, 1751017500]]  [['LED', 'FCO']]             7.17
#
#                       tags is_mixed  idx currency  price       url  \
# 357  ['convenient_ticket']      NaN  387      rub  77776  18300356
# 356  ['convenient_ticket']      NaN  387      rub  77776  18300355
#
#           flights_baggage                      flights_handbags  \
# ...

# %%
print(viable_proposals.shape)

viable_proposals.drop_duplicates(subset=["idx_new", "price"], inplace=True)
print(viable_proposals.shape)
# Out:
# (944, 39)
# (875, 39)

# %%
viable_proposals[viable_proposals.price == 77776]
# Out:
#                                                segment  total_duration  \
# 357  [{'flight': [{'aircraft': 'Airbus A330-200', '...             550
#
#      stops_airports  max_stops  max_stop_duration carriers segment_durations  \
# 357  ['IST', 'FCO']          1                160   ['TK']            (550,)
#
#                   segments_time segments_airports  segments_rating  \
# 357  [[1750988100, 1751017500]]  [['LED', 'FCO']]             7.17
#
#                       tags is_mixed  idx currency  price       url  \
# 357  ['convenient_ticket']      NaN  387      rub  77776  18300356
#
#           flights_baggage                      flights_handbags  \
# 357  [['1PC30', '1PC30']]  [['1PC8x40x23x55', '1PC8x40x23x55']]
#
#                         flight_additional_tariff_infos viable_handbags  \
# 357  [[{'return_before_flight': {'available': True}...   1PC8x40x23x55
#
#     viable_baggage  has_handbags  has_baggage  \
# 357          1PC30          True         True
#
# ...

# %%
indices_already_displayed = []

smallest_durations_by_group = viable_proposals.groupby("idx_new")[
    "total_duration"
].min()
smallest_durations = smallest_durations_by_group.nsmallest(2).values
min_price_indices = (
    viable_proposals[
        viable_proposals.total_duration.isin(smallest_durations)
    ]
    .groupby("idx_new")["price"]
    .idxmin()
)
fastest_optimal = viable_proposals.loc[min_price_indices]

# %%
fastest_optimal
# Out:
#                                                segment  total_duration  \
# 31   [{'flight': [{'aircraft': 'Airbus A321-100/200...             535
# 405  [{'flight': [{'aircraft': 'Airbus A330-200', '...             550
#
#      stops_airports  max_stops  max_stop_duration carriers segment_durations  \
# 31   ['SAW', 'FCO']          1                135   ['PC']            (535,)
# 405  ['IST', 'FCO']          1                160   ['TK']            (550,)
#
#                   segments_time segments_airports  segments_rating  \
# 31   [[1750992900, 1751021400]]  [['LED', 'FCO']]            7.679
# 405  [[1750988100, 1751017500]]  [['LED', 'FCO']]            7.170
#
#                       tags is_mixed  idx currency  price       url  \
# 31   ['convenient_ticket']      NaN   28      rub  43970   7000001
# 405  ['convenient_ticket']      NaN  422      rub  77776  18300359
#
#           flights_baggage                      flights_handbags  \
# ...

# %%
df["idx_new"] = df.groupby(
    [
        "total_duration",
        "max_stops",
        "max_stop_duration",
        "segment_durations",
        "airlines_list_to",
        "airlines_list_back",
        "flight_to_time_raw",
        "flight_back_time_raw",
    ]
).ngroup()

# %%
df    [[
        "total_duration",
        "max_stops",
        "max_stop_duration",
        "segment_durations",
        "airlines_list_to",
        "airlines_list_back",
        "flight_to_time_raw",
        "flight_back_time_raw",
    ]]
# Out:
#       total_duration  max_stops  max_stop_duration segment_durations  \
# 0               1600          1               1190            [1600]
# 1               1290          1                880            [1290]
# 2                835          1                440             [835]
# 3               1125          1                725            [1125]
# 4               1375          1                985            [1375]
# ...              ...        ...                ...               ...
# 1539            2090          2               1080            [2090]
# 1540            1965          1               1570            [1965]
# 1541            1965          1               1570            [1965]
# 1542            2275          1               1880            [2275]
# 1543            2025          1               1620            [2025]
#
#         airlines_list_to airlines_list_back flight_to_time_raw  \
# 0           ('TK', 'TK')                 ()              12:50
# ...

# %%
tuple([1,2,3,4,1])
# Out:
# (1, 2, 3, 4, 1)

# %%
smallest_durations_by_group = df.groupby("idx_new")["total_duration"].min()
df_smallest_duration = smallest_durations_by_group.nsmallest(2).values

df_smallest_duration
# Out:
# array([535, 550])

# %%
min_price_indices = df[df.total_duration.isin(df_smallest_duration)].groupby("idx_new")["price"].idxmin()
df_min_price_by_group = df.loc[min_price_indices]

df_min_price_by_group
# Out:
#                                                segment  total_duration  \
# 50   [{'flight': [{'aircraft': 'Airbus A321-100/200...             535
# 891  [{'flight': [{'aircraft': 'Airbus A330-200', '...             550
#
#      stops_airports  max_stops  max_stop_duration carriers segment_durations  \
# 50   ['SAW', 'FCO']          1                135   ['PC']             [535]
# 891  ['IST', 'FCO']          1                160   ['TK']             [550]
#
#                   segments_time segments_airports  segments_rating  \
# 50   [[1750992900, 1751021400]]  [['LED', 'FCO']]            7.679
# 891  [[1750988100, 1751017500]]  [['LED', 'FCO']]            7.170
#
#                       tags is_mixed  idx currency  price       url  \
# 50   ['convenient_ticket']      NaN   49      rub  43970   7000001
# 891  ['convenient_ticket']      NaN  855      rub  77776  18300535
#
#           flights_baggage                      flights_handbags  \
# ...

# %%
df["total_duration"].nsmallest(10).unique()
# Out:
# array([535])

# %%
df[df.idx == 802]
# Out:
#                                                segment  total_duration  \
# 811  [{'flight': [{'aircraft': 'Airbus A321 (sharkl...            1125
# 812  [{'flight': [{'aircraft': 'Airbus A321 (sharkl...            1125
# 813  [{'flight': [{'aircraft': 'Airbus A321 (sharkl...            1125
# 814  [{'flight': [{'aircraft': 'Airbus A321 (sharkl...            1125
# 815  [{'flight': [{'aircraft': 'Airbus A321 (sharkl...            1125
# 816  [{'flight': [{'aircraft': 'Airbus A321 (sharkl...            1125
#
#      stops_airports  max_stops  max_stop_duration carriers segment_durations  \
# 811  ['IST', 'FCO']          1                725   ['TK']            [1125]
# 812  ['IST', 'FCO']          1                725   ['TK']            [1125]
# 813  ['IST', 'FCO']          1                725   ['TK']            [1125]
# 814  ['IST', 'FCO']          1                725   ['TK']            [1125]
# 815  ['IST', 'FCO']          1                725   ['TK']            [1125]
# ...

# %%
df.idx.value_counts()
# Out:
# idx
# 802     6
# 803     6
# 824     6
# 418     5
# 419     5
#        ..
# 501     1
# 502     1
# 504     1
# 505     1
# 1273    1
# Name: count, Length: 896, dtype: int64

# %%
df.idx_new.value_counts()
# Out:
# idx_new
# 8      15
# 103    14
# 151    14
# 36     13
# 158    13
#        ..
# 123     1
# 43      1
# 141     1
# 94      1
# 381     1
# Name: count, Length: 688, dtype: int64

# %%
df.sort_values("max_stops", ascending=True)
# Out:
#                                                segment  total_duration  \
# 0    [{'flight': [{'aircraft': 'Airbus A321-100/200...             710
# 783  [{'flight': [{'aircraft': 'Airbus A321-100/200...            1290
# 724  [{'flight': [{'aircraft': 'Airbus A321-100/200...             985
# 723  [{'flight': [{'aircraft': 'Airbus A321-100/200...             985
# 722  [{'flight': [{'aircraft': 'Airbus A321-100/200...             575
# ..                                                 ...             ...
# 623  [{'flight': [{'aircraft': 'Sukhoi Superjet 100...            1915
# 545  [{'flight': [{'aircraft': 'Airbus A321-100/200...            3635
# 546  [{'flight': [{'aircraft': 'Airbus A321-100/200...            3635
# 543  [{'flight': [{'aircraft': 'Airbus A321-100/200...            3635
# 544  [{'flight': [{'aircraft': 'Airbus A321-100/200...            3635
#
#                           stops_airports  max_stops  max_stop_duration  \
# ...

# %%
eval(df.iloc[1].segment)
# Out:
# [{'flight': [{'aircraft': 'Sukhoi Superjet 100',
#     'arrival': 'SVO',
#     'arrival_date': '2025-06-27',
#     'arrival_time': '13:00',
#     'arrival_timestamp': 1751018400,
#     'delay': 0,
#     'departure': 'LED',
#     'departure_date': '2025-06-27',
#     'departure_time': '11:30',
#     'departure_timestamp': 1751013000,
#     'duration': 90,
#     'equipment': 'SU9',
#     'local_arrival_timestamp': 1751029200,
#     'local_departure_timestamp': 1751023800,
#     'marketing_carrier': 'SU',
#     'number': '6168',
#     'operating_carrier': 'FV',
#     'operated_by': 'FV',
#     'rating': 0,
#     'technical_stops': None,
#     'trip_class': 'Y'},
#    {'aircraft': 'Boeing 737-800 (winglets)',
#     'arrival': 'EVN',
#     'arrival_date': '2025-06-27',
#     'arrival_time': '19:10',
#     'arrival_timestamp': 1751037000,
#     'delay': 100,
#     'departure': 'SVO',
#     'departure_date': '2025-06-27',
#     'departure_time': '14:40',
# ...
